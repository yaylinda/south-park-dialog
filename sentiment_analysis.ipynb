# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.head()
# Out:
#    Season  Episode Character  \
# 0      18        9    Gerald
# 1      18        9      Kyle
# 2      18        9    Gerald
# 3      18        9      Kyle
# 4      18        9    Gerald
#
#                                                 Line
# 0  There you are, Kyle. I was gonna see if you an...
# 1  Nono Dad, please. I just got Call Of Duty: Adv...
# 2  It's your day off. You boys really wanna spend...
# 3  Please Dad, I've been looking forward to this ...
# 4  All right.  I swear I'll never understand you ...

# %%
import nltk
from nltk.corpus import stopwords

# %%
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px 

nltk.download('stopwords')
from nltk.corpus import stopwords # to get rid of StopWords 

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lindazheng/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def get_words_for_character(character):

    words = []

    for line in df[df["Character"] == character].Line:
        for word in line.split():
            words.append(word.strip("\n"))

    return words

# %%
stan_words = get_words_for_character("Stan")

# %%
stan_words
# Out:
# ['I',
#  "don't",
#  'get',
#  'it.',
#  'The',
#  'whole',
#  'fun',
#  'of',
#  'Call',
#  'of',
#  'Duty',
#  'is',
#  'that',
#  'you',
#  'get',
#  'to',
#  'do',
#  'the',
#  'shooting.',
#  'I',
#  "don't",
#  'get',
#  'it.',
#  'The',
#  'whole',
#  'fun',
#  'of',
#  'Call',
#  'of',
#  'Duty',
#  'is',
#  'that',
#  'you',
#  'get',
#  'to',
#  'do',
#  'the',
#  'shooting.',
#  'I',
#  "don't",
#  'get',
#  'it.',
#  'The',
#  'whole',
#  'fun',
#  'of',
#  'Call',
#  'of',
#  'Duty',
#  'is',
#  'that',
#  'you',
#  'get',
#  'to',
#  'do',
#  'the',
#  'shooting.',
#  'What',
#  'are',
#  'you',
#  'talking',
#  'about?',
#  'Hey,',
#  "what's",
#  'up?',
#  'Oh',
#  'no,',
#  'what',
#  'now?',
#  'Yeah?',
#  'Dude,',
#  'video',
#  'games',
#  'are',
#  'meant',
#  'to',
#  'be',
#  'played',
#  'in',
#  'a',
#  'living',
#  'room,',
#  'not',
#  'something',
#  'to',
#  'watch',
#  'people',
#  'comment',
#  'on!',
#  'Grandpa?',
#  'Oh,',
#  'is',
#  'that',
# ...

# %%
wordcloud = WordCloud().generate(stan_words)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ----------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-41-74abef052a67> in <module>
# ----> 1 wordcloud = WordCloud().generate(stan_words)
#       2
#       3 # Display the generated image:
#       4 plt.imshow(wordcloud, interpolation='bilinear')
#       5 plt.axis("off")
#
# /usr/local/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# /usr/local/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# /usr/local/lib/python3.7/site-packages/wordcloud/wordcloud.py in process_text(self, text)
# ...

# %%
# Out:
# "I don't get it. The whole fun of\xa0Call of Duty\xa0is that you get to do the shooting.\n"

# %%
# Out:
# ----------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-27-d65ad71095c2> in <module>
#       1 stan_lines = [line for line in character_text_df_dict["Stan"].Line]
# ----> 2 stan_words = [line.strip("\n") for line in stan_lines.split()]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
stan_words[1:10]
# Out:
# ["I don't get it. The whole fun of\xa0Call of Duty\xa0is that you get to do the shooting.",
#  "I don't get it. The whole fun of\xa0Call of Duty\xa0is that you get to do the shooting.",
#  'What are you talking about?',
#  "Hey, what's up?",
#  'Oh no, what now?',
#  'Yeah?',
#  'Dude, video games are meant to be played in a living room, not something to watch people comment on!',
#  'Grandpa?',
#  'Oh, is that right?! Do you even know how to multiply?!']

# %%
test = "linda zheng\na v"
[x.strip("\n") for x in test.split()]
# Out:
# ['linda', 'zheng', 'a', 'v']
